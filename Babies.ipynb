# %% [markdown]
# <a href="https://colab.research.google.com/github/demax44/Classification/blob/master/Babies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
BabyDataframe=pd.read_csv('/content/yob1882.txt')

# %%
BabyDataframe
# Out:
#            Mary  F  8148
# 0          Anna  F  3143
# 1          Emma  F  2303
# 2     Elizabeth  F  2186
# 3        Minnie  F  2004
# 4      Margaret  F  1821
# ...         ... ..   ...
# 2121       Wirt  M     5
# 2122    Woodson  M     5
# 2123      Woody  M     5
# 2124     Worley  M     5
# 2125        Zed  M     5
#
# [2126 rows x 3 columns]

# %%
BabyDataframe=pd.read_csv('/content/yob1880.txt',header=None,names=["Name","Gender","Count"])

# %%
BabyDataframe
# Out:
#            Name Gender  Count
# 0          Mary      F   7065
# 1          Anna      F   2604
# 2          Emma      F   2003
# 3     Elizabeth      F   1939
# 4        Minnie      F   1746
# ...         ...    ...    ...
# 1995     Woodie      M      5
# 1996     Worthy      M      5
# 1997     Wright      M      5
# 1998       York      M      5
# 1999  Zachariah      M      5
#
# [2000 rows x 3 columns]

# %%
BabyDataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2000 non-null   object
#  1   Gender  2000 non-null   object
#  2   Count   2000 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 47.0+ KB

# %%
BabyDataframe.describe()
# Out:
#              Count
# count  2000.000000
# mean    100.742000
# std     466.109199
# min       5.000000
# 25%       7.000000
# 50%      13.000000
# 75%      41.250000
# max    9655.000000

# %%
BabyDataframe.min()
# Out:
# Name      Aaron
# Gender        F
# Count         5
# dtype: object

# %%
BabyDataframe.max()
# Out:
# Name      Zula
# Gender       M
# Count     9655
# dtype: object

# %% [markdown]
# Merge many datasets

# %%
BabyDataframe=pd.read_csv('/content/yob1882.txt',header=None,names=["Name","Gender","Count"])
BabyDataframe
# Out:
#            Name Gender  Count
# 0          Mary      F   8148
# 1          Anna      F   3143
# 2          Emma      F   2303
# 3     Elizabeth      F   2186
# 4        Minnie      F   2004
# ...         ...    ...    ...
# 2122       Wirt      M      5
# 2123    Woodson      M      5
# 2124      Woody      M      5
# 2125     Worley      M      5
# 2126        Zed      M      5
#
# [2127 rows x 3 columns]

# %%
BabyDataframe83=pd.read_csv('/content/yob1881.txt',header=None,names=['Name','Gender','Count'])
BabyDataframe83
# Out:
#            Name Gender  Count
# 0          Mary      F   6919
# 1          Anna      F   2698
# 2          Emma      F   2034
# 3     Elizabeth      F   1852
# 4      Margaret      F   1658
# ...         ...    ...    ...
# 1930     Wiliam      M      5
# 1931     Wilton      M      5
# 1932       Wing      M      5
# 1933       Wood      M      5
# 1934     Wright      M      5
#
# [1935 rows x 3 columns]

# %% [markdown]
# Concatentate the data

# %%
pd.concat(objs=[BabyDataframe,BabyDataframe83],axis=0,keys=[1880,1881],names=['Year'])
# Out:
#                 Name Gender  Count
# Year
# 1880 0          Mary      F   7065
#      1          Anna      F   2604
#      2          Emma      F   2003
#      3     Elizabeth      F   1939
#      4        Minnie      F   1746
# ...              ...    ...    ...
# 1881 1930     Wiliam      M      5
#      1931     Wilton      M      5
#      1932       Wing      M      5
#      1933       Wood      M      5
#      1934     Wright      M      5
#
# [3935 rows x 3 columns]

# %%
pd.concat(objs=[BabyDataframe,BabyDataframe83],axis=0,keys=[1880,1881],names=['Year']).droplevel(-1).reset_index()
# Out:
#       Year       Name Gender  Count
# 0     1880       Mary      F   7065
# 1     1880       Anna      F   2604
# 2     1880       Emma      F   2003
# 3     1880  Elizabeth      F   1939
# 4     1880     Minnie      F   1746
# ...    ...        ...    ...    ...
# 3930  1881     Wiliam      M      5
# 3931  1881     Wilton      M      5
# 3932  1881       Wing      M      5
# 3933  1881       Wood      M      5
# 3934  1881     Wright      M      5
#
# [3935 rows x 4 columns]

# %%
pd.read_csv('/content/yob{}.txt'.format(1880),header=None,names=["Name","Gender","Count"])
# Out:
#            Name Gender  Count
# 0          Mary      F   7065
# 1          Anna      F   2604
# 2          Emma      F   2003
# 3     Elizabeth      F   1939
# 4        Minnie      F   1746
# ...         ...    ...    ...
# 1995     Woodie      M      5
# 1996     Worthy      M      5
# 1997     Wright      M      5
# 1998       York      M      5
# 1999  Zachariah      M      5
#
# [2000 rows x 3 columns]

# %% [markdown]
# Make a list and iterate

# %%
years=list(range(1880,1971))
years
# Out:
# [1880,
#  1881,
#  1882,
#  1883,
#  1884,
#  1885,
#  1886,
#  1887,
#  1888,
#  1889,
#  1890,
#  1891,
#  1892,
#  1893,
#  1894,
#  1895,
#  1896,
#  1897,
#  1898,
#  1899,
#  1900,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1907,
#  1908,
#  1909,
#  1910,
#  1911,
#  1912,
#  1913,
#  1914,
#  1915,
#  1916,
#  1917,
#  1918,
#  1919,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1926,
#  1927,
#  1928,
#  1929,
#  1930,
#  1931,
#  1932,
#  1933,
#  1934,
#  1935,
#  1936,
#  1937,
#  1938,
#  1939,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970]

# %%
Baby_namesyears=[]
for year in years:
  BabyData=pd.read_csv('/content/yob{}.txt'.format(year),header=None,names=["Name","Gender","Count"])
  Baby_namesyears.append(BabyData)

# %%
Baby_namesyears
# Out:
# [           Name Gender  Count
#  0          Mary      F   7065
#  1          Anna      F   2604
#  2          Emma      F   2003
#  3     Elizabeth      F   1939
#  4        Minnie      F   1746
#  ...         ...    ...    ...
#  1995     Woodie      M      5
#  1996     Worthy      M      5
#  1997     Wright      M      5
#  1998       York      M      5
#  1999  Zachariah      M      5
#
#  [2000 rows x 3 columns],            Name Gender  Count
#  0          Mary      F   6919
#  1          Anna      F   2698
#  2          Emma      F   2034
#  3     Elizabeth      F   1852
#  4      Margaret      F   1658
#  ...         ...    ...    ...
#  1930     Wiliam      M      5
#  1931     Wilton      M      5
#  1932       Wing      M      5
#  1933       Wood      M      5
#  1934     Wright      M      5
#
#  [1935 rows x 3 columns],            Name Gender  Count
#  0          Mary      F   8148
#  1          Anna      F   3143
#  2          Emma      F   2303
# ...

# %%
len(Baby_namesyears)
# Out:
# 91

# %%
BabyB=pd.concat(Baby_namesyears,axis=0,keys=years,names=['Year']).droplevel(-1).reset_index()

# %%
BabyB
# Out:
#         Year       Name Gender  Count
# 0       1880       Mary      F   7065
# 1       1880       Anna      F   2604
# 2       1880       Emma      F   2003
# 3       1880  Elizabeth      F   1939
# 4       1880     Minnie      F   1746
# ...      ...        ...    ...    ...
# 711421  1970       Zaid      M      5
# 711422  1970     Zalmen      M      5
# 711423  1970     Zavier      M      5
# 711424  1970    Zebulon      M      5
# 711425  1970        Zon      M      5
#
# [711426 rows x 4 columns]

# %%
BabyB.to_csv('US_infantnames.csv',index=False)

# %%
pd.read_csv('US_infantnames.csv')
# Out:
#         Year       Name Gender  Count
# 0       1880       Mary      F   7065
# 1       1880       Anna      F   2604
# 2       1880       Emma      F   2003
# 3       1880  Elizabeth      F   1939
# 4       1880     Minnie      F   1746
# ...      ...        ...    ...    ...
# 711421  1970       Zaid      M      5
# 711422  1970     Zalmen      M      5
# 711423  1970     Zavier      M      5
# 711424  1970    Zebulon      M      5
# 711425  1970        Zon      M      5
#
# [711426 rows x 4 columns]
